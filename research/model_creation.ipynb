# %% [markdown]
# # Model Building

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.metrics.pairwise import cosine_similarity

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
books_df = pd.read_csv(r'../artifacts/data_ingestion/books.csv')
ratings_df = pd.read_csv(r'../artifacts/data_ingestion/ratings.csv')
users_df = pd.read_csv(r'../artifacts/data_ingestion/users.csv')

# %%
books_with_ratings = pd.merge(books_df, ratings_df,on='ISBN')

# %%
books_with_ratings.head()
# Out:
#         ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  195153448  Classical Mythology    Mark P. O. Morford                2002
# 1    2005018         Clara Callan  Richard Bruce Wright                2001
# 2    2005018         Clara Callan  Richard Bruce Wright                2001
# 3    2005018         Clara Callan  Richard Bruce Wright                2001
# 4    2005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-L  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#    User-ID  Book-Rating
# 0        2            0
# 1        8            5
# 2    11400            0
# 3    11676            8
# 4    41385            0

# %%
books_with_ratings.shape
# Out:
# (1031661, 8)

# %%
x = books_with_ratings.groupby('User-ID').count()['Book-Rating'] > 100

# %%
knowledgeable_reader = x[x].index

# %%
knowledgeable_reader
# Out:
# Index([   254,    507,    882,   1424,   1435,   1733,   1903,   2033,   2110,
#          2276,
#        ...
#        275020, 275970, 276463, 276680, 277427, 277478, 277639, 278137, 278188,
#        278418],
#       dtype='int64', name='User-ID', length=1649)

# %%
knowledgeable_reader_df = books_with_ratings[books_with_ratings['User-ID'].isin(knowledgeable_reader)]

# %%
knowledgeable_reader_df.head()
# Out:
#        ISBN    Book-Title           Book-Author Year-Of-Publication  \
# 3   2005018  Clara Callan  Richard Bruce Wright                2001
# 6   2005018  Clara Callan  Richard Bruce Wright                2001
# 7   2005018  Clara Callan  Richard Bruce Wright                2001
# 10  2005018  Clara Callan  Richard Bruce Wright                2001
# 13  2005018  Clara Callan  Richard Bruce Wright                2001
#
#                 Publisher                                        Image-URL-L  \
# 3   HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 6   HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 7   HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 10  HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 13  HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#     User-ID  Book-Rating
# 3     11676            8
# 6     85526            0
# 7     96054            0
# 10   177458            0
# 13   219008            7

# %%
y = knowledgeable_reader_df.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
final_df = knowledgeable_reader_df[knowledgeable_reader_df['Book-Title'].isin(famous_books)]

# %%
final_df
# Out:
#               ISBN                                      Book-Title  \
# 31       399135782                          The Kitchen God's Wife
# 32       399135782                          The Kitchen God's Wife
# 33       399135782                          The Kitchen God's Wife
# 34       399135782                          The Kitchen God's Wife
# 38       399135782                          The Kitchen God's Wife
# ...            ...                                             ...
# 1029127  449001164                                     The Promise
# 1029340  743527631                        The Pillars of the Earth
# 1029342  745168086                             The Handmaid's Tale
# 1031019  553290703                                       Lightning
# 1031507  395647398  The Two Towers (The Lord of the Rings, Part 2)
#
#               Book-Author Year-Of-Publication            Publisher  \
# 31                Amy Tan                1991     Putnam Pub Group
# 32                Amy Tan                1991     Putnam Pub Group
# 33                Amy Tan                1991     Putnam Pub Group
# 34                Amy Tan                1991     Putnam Pub Group
# 38                Amy Tan                1991     Putnam Pub Group
# ...                   ...                 ...                  ...
# 1029127       CHAIM POTOK                1997     Ballantine Books
# 1029340       Ken Follett                2002               Encore
# 1029342   Margaret Atwood                1999  Chivers Audio Books
# 1031019   Patricia Potter                1992         Bantam Books
# 1031507  J. R. R. Tolkien                1992     Houghton Mifflin
#
#                                                Image-URL-L  User-ID  \
# 31       http://images.amazon.com/images/P/0399135782.0...    11676
# 32       http://images.amazon.com/images/P/0399135782.0...    29526
# 33       http://images.amazon.com/images/P/0399135782.0...    36836
# 34       http://images.amazon.com/images/P/0399135782.0...    46398
# 38       http://images.amazon.com/images/P/0399135782.0...   113270
# ...                                                    ...      ...
# 1029127  http://images.amazon.com/images/P/0449001164.0...   239594
# 1029340  http://images.amazon.com/images/P/0743527631.0...   240144
# 1029342  http://images.amazon.com/images/P/0745168086.0...   240144
# 1031019  http://images.amazon.com/images/P/0553290703.0...   244685
# 1031507  http://images.amazon.com/images/P/0395647398.0...   259901
#
#          Book-Rating
# 31                 9
# 32                 9
# 33                 0
# 34                 9
# 38                 0
# ...              ...
# 1029127            7
# 1029340            0
# 1029342            0
# 1031019            9
# 1031507           10
#
# [97618 rows x 8 columns]

# %%
encoded_df = final_df.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
encoded_df.fillna(0,inplace=True)

# %%
encoded_df
# Out:
# User-ID                                             254     507     882     \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             1424    1435    1733    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             1903    2033    2110    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2276    ...  275020  \
# Book-Title                                                  ...
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2010: Odyssey Two                                      0.0  ...     0.0
# 204 Rosewood Lane                                      0.0  ...     0.0
# 24 Hours                                               0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             275970  276463  276680  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             277427  277478  277639  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                              10.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             278137  278188  278418
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [1071 rows x 1635 columns]

# %%
similarity_scores = cosine_similarity(encoded_df)

# %%
similarity_scores.shape
# Out:
# (1071, 1071)

# %%
def recommender(book_name):
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    books = []
    for i in similar_items:
        item = []
        temp_df = books_df[books_df['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-L'].values))
        
        books.append(item)
    
    return books

# %%
recommender('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.LZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.LZZZZZZZ.jpg'],
#  ["Slaughterhouse Five or the Children's Crusade: A Duty Dance With Death",
#   'Kurt Vonnegut',
#   'http://images.amazon.com/images/P/0440180295.01.LZZZZZZZ.jpg'],
#  ['Awakening',
#   'Kate Chopin',
#   'http://images.amazon.com/images/P/0380002450.01.LZZZZZZZ.jpg']]

# %%
pickle.dump(encoded_df,open('pt.pkl','wb'))
pickle.dump(books_df,open('books_df.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))
