# %%
import os
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r'../artifacts/data_ingestion/data.csv')
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_14844\115887715.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r'../artifacts/data_ingestion/data.csv')

# %%
data
# Out:
#          Unnamed: 0        ISBN  \
# 0                 0   195153448
# 1                 1     2005018
# 2                 2     2005018
# 3                 3     2005018
# 4                 4     2005018
# ...             ...         ...
# 1031131     1031131   440400988
# 1031132     1031132   525447644
# 1031133     1031133  006008667X
# 1031134     1031134   192126040
# 1031135     1031135   767409752
#
#                                                 Book-Title  \
# 0                                      Classical Mythology
# 1                                             Clara Callan
# 2                                             Clara Callan
# 3                                             Clara Callan
# 4                                             Clara Callan
# ...                                                    ...
# 1031131                         There's a Bat in Bunk Five
# 1031132                            From One to One Hundred
# ...

# %%
data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
data
# Out:
#                ISBN                                         Book-Title  \
# 0         195153448                                Classical Mythology
# 1           2005018                                       Clara Callan
# 2           2005018                                       Clara Callan
# 3           2005018                                       Clara Callan
# 4           2005018                                       Clara Callan
# ...             ...                                                ...
# 1031131   440400988                         There's a Bat in Bunk Five
# 1031132   525447644                            From One to One Hundred
# 1031133  006008667X  Lily Dale : The True Story of the Town that Ta...
# 1031134   192126040                        Republic (World's Classics)
# 1031135   767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   Book-Author Year-Of-Publication  \
# 0          Mark P. O. Morford                2002
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1031136 entries, 0 to 1031135
# Data columns (total 9 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   ISBN                 1031136 non-null  object
#  1   Book-Title           1031136 non-null  object
#  2   Book-Author          1031134 non-null  object
#  3   Year-Of-Publication  1031136 non-null  object
#  4   Publisher            1031134 non-null  object
#  5   Image-URL-L          1031132 non-null  object
#  6   Location             1031136 non-null  object
#  7   Age                  753301 non-null   float64
#  8   Book-Rating          1031136 non-null  int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 70.8+ MB

# %%
data['Book-Rating'] = data.astype({'Book-Rating': 'int32'}).dtypes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1031136 entries, 0 to 1031135
# Data columns (total 9 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   ISBN                 1031136 non-null  object
#  1   Book-Title           1031136 non-null  object
#  2   Book-Author          1031134 non-null  object
#  3   Year-Of-Publication  1031136 non-null  object
#  4   Publisher            1031134 non-null  object
#  5   Image-URL-L          1031132 non-null  object
#  6   Location             1031136 non-null  object
#  7   Age                  753301 non-null   float64
#  8   Book-Rating          0 non-null        object
# dtypes: float64(1), object(8)
# memory usage: 70.8+ MB
